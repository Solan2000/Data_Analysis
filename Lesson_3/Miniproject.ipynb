# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
user_data=pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/3_user_data.csv')
user_logs=pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/3_logs.csv')

df=user_data.merge(user_logs, on='client', how='inner')
df=df.query("platform=='computer' and success == True ")

plt.figure(figsize=(12, 8))
sns.countplot(df.age)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
