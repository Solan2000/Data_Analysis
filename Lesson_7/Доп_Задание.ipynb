# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=sunflowers') #2 задание
res = r.json()
sunflower_ids = res.get('objectIDs', [])

# %%
sunflower_ids
# Out:
# [436524,
#  484935,
#  437112,
#  210191,
#  431264,
#  397949,
#  656530,
#  480725,
#  486590,
#  485308,
#  375281,
#  705155,
#  11922,
#  816522,
#  343052,
#  20141,
#  347980,
#  208554,
#  403496,
#  360837,
#  207869,
#  437115,
#  400581,
#  423400,
#  707887,
#  223828,
#  682927,
#  57922,
#  79739,
#  193938,
#  649813,
#  339347,
#  437329,
#  208218,
#  202228,
#  437984,
#  761604,
#  696949,
#  704667,
#  822589,
#  822590,
#  436580,
#  436252,
#  363282,
#  207753,
#  437526,
#  822570,
#  487043,
#  203893,
#  367434,
#  190739,
#  2032,
#  423237,
#  262423,
#  839296,
#  367817,
#  13644,
#  18362,
#  820022,
#  648617,
#  761731,
#  814626,
#  892559,
#  207967,
#  626832,
#  2019,
#  701016,
#  262430,
#  262428,
#  841928,
#  262378,
#  707697,
#  205386,
#  436535,
#  426804,
#  633526,
#  369073,
#  747779,
#  436529,
#  436121,
#  436144,
#  852414,
#  427872,
#  895564,
#  436530,
#  436534,
#  724844,
#  437980,
#  631808,
#  396836,
#  834765,
# ...

# %%
r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/437980')
obj_test = r_test.json() #3 задание

# %%
obj_test
# Out:
# {'objectID': 437980,
#  'isHighlight': False,
#  'accessionNumber': '49.30',
#  'accessionYear': '1949',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/ep/original/DP130999.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/ep/web-large/DP130999.jpg',
#  'additionalImages': [],
#  'constituents': [{'constituentID': 161947,
#    'role': 'Artist',
#    'name': 'Vincent van Gogh',
#    'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500115588',
#    'constituentWikidata_URL': 'https://www.wikidata.org/wiki/Q5582',
#    'gender': ''}],
#  'department': 'European Paintings',
#  'objectName': 'Painting',
#  'title': 'Cypresses',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': 'Artist',
#  'artistPrefix': '',
#  'artistDisplayName': 'Vincent van Gogh',
#  'artistDisplayBio': 'Dutch, Zundert 1853–1890 Auvers-sur-Oise',
#  'artistSuffix': '',
# ...

# %%
#4 задание

# Список для хранения данных каждого объекта
objects_data = []

# Цикл для запроса данных по каждому ID
for object_id in sunflower_ids:
    object_url = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{object_id}'
    response = requests.get(object_url)
    data = response.json()

    # Сбор необходимой информации
    object_info = {
        "objectID": data.get("objectID"),
        "title": data.get("title"),
        "artistDisplayName": data.get("artistDisplayName"),
        "department": data.get("department"),
        "objectBeginDate": data.get("objectBeginDate"),
        "objectEndDate": data.get("objectEndDate"),
        "period": data.get("period"),
        "objectName": data.get("objectName"),
        "culture": data.get("culture")
    }

    objects_data.append(object_info)

# Создание датафрейма
df = pd.DataFrame(objects_data)

# Подсчёт объектов японской культуры
japanese_culture_count = df[df['culture'] == "Japan"].shape[0]

print(f"Количество объектов японской культуры: {japanese_culture_count}")
# Out:
# Количество объектов японской культуры: 1

# %%
df
# Out:
#     objectID                                              title  \
# 0   436524.0                                         Sunflowers
# 1   484935.0                                         Sunflowers
# 2   437112.0                              Bouquet of Sunflowers
# 3   210191.0                               Vase with sunflowers
# 4   431264.0                                         Sunflowers
# ..       ...                                                ...
# 88       NaN                                               None
# 89  396836.0                                The Aesthetic Craze
# 90  834765.0           A Child's Garden, from "Picture Poesies"
# 91  834580.0  A Life in a Year–The Garden–Noon, from "Pictur...
# 92  834585.0  A Life in a Year–The Garden–Noon, from "Pictur...
#
#            artistDisplayName                              department  \
# 0           Vincent van Gogh                      European Paintings
# ...

# %%
#5 задание
# Запрос к API для получения списка ID
response = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
data = response.json()
cat_ids = data.get('objectIDs', [])[:1000]  # Получение первых 1000 ID

# Сбор данных о каждом объекте
objects_data = []
for object_id in cat_ids:
    object_url = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{object_id}'
    response = requests.get(object_url)
    data = response.json()

    object_info = {
        "objectID": data.get("objectID"),
        "title": data.get("title"),
        "artistDisplayName": data.get("artistDisplayName"),
        "department": data.get("department"),
        "objectBeginDate": data.get("objectBeginDate"),
        "objectEndDate": data.get("objectEndDate"),
        "period": data.get("period"),
        "objectName": data.get("objectName"),
        "culture": data.get("culture")
    }

    objects_data.append(object_info)

# Создание датафрейма
df = pd.DataFrame(objects_data)

# Анализ данных
most_common_period = df['period'].value_counts().idxmax()

# %%
most_common_period
# Out:
# 'Edo period (1615–1868)'
