# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import numpy as np
import statsmodels.api as sm

# %%
cars = pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/cars.csv')
cars
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
cars.dtypes
# Out:
# symboling             int64
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# company              object
# dtype: object

# %%
cars['company'] = cars.CarName.apply(lambda x: x.split(' ')[0])

# %%
cars = cars.drop(columns=['CarName','car_ID'])

# %%
cars['company'] = cars.company.replace({'maxda':'mazda','porcshce':'porsche','toyouta':'toyota','vokswagen':'volkswagen','vw':'volkswagen'})

# %%
cars['company'] = cars.company.str.lower()

# %%
cars.company.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
cars.corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
# Выбираем необходимые колонки для анализа
selected_columns = ['company', 'fueltype', 'aspiration', 'carbody', 'drivewheel', 
                    'wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginetype', 
                    'cylindernumber', 'enginesize', 'boreratio', 'horsepower', 'price']

# Создаем новый DataFrame с выбранными колонками
сars = cars_data[selected_columns]

# Вычисляем корреляцию между 'price' и 'horsepower'
correlation_price_horsepower = cars['price'].corr(selected_data['horsepower'])

# Округляем результат до двух знаков после запятой
correlation_price_horsepower_rounded = round(correlation_price_horsepower, 2)

correlation_price_horsepower_rounded
# Out:
# 0.81

# %%
np.round(0.808139,2)
# Out:
# 0.81

# %%
df_dummy = pd.get_dummies(data=cars[['company', 'fueltype', 'aspiration','carbody', 'drivewheel', 'wheelbase', 'carlength','carwidth', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 'price']], drop_first = True)

# %%
df_dummy
# Out:
#      wheelbase  carlength  carwidth  curbweight  enginesize  boreratio  \
# 0         88.6      168.8      64.1        2548         130       3.47
# 1         88.6      168.8      64.1        2548         130       3.47
# 2         94.5      171.2      65.5        2823         152       2.68
# 3         99.8      176.6      66.2        2337         109       3.19
# 4         99.4      176.6      66.4        2824         136       3.19
# ..         ...        ...       ...         ...         ...        ...
# 200      109.1      188.8      68.9        2952         141       3.78
# 201      109.1      188.8      68.8        3049         141       3.78
# 202      109.1      188.8      68.9        3012         173       3.58
# 203      109.1      188.8      68.9        3217         145       3.01
# 204      109.1      188.8      68.9        3062         141       3.78
#
#      horsepower    price  company_audi  company_bmw  ...  enginetype_ohc  \
# ...

# %%
import statsmodels.api as sm

# OLS regression requires an additional column for the intercept
X=df_dummy['horsepower']
y=df_dummy['price']
X_with_intercept = sm.add_constant(X)

# Create an OLS model
ols_model = sm.OLS(y, X_with_intercept)

# Fit the model
results = ols_model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     382.2
# Date:                Mon, 22 Jan 2024   Prob (F-statistic):           1.48e-48
# Time:                        22:19:56   Log-Likelihood:                -2024.0
# No. Observations:                 205   AIC:                             4052.
# Df Residuals:                     203   BIC:                             4059.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3721.7615    929.849     -4.003      0.000   -5555.163   -1888.360
# ...

# %%
df_dummy = pd.get_dummies(data=cars[['company', 'fueltype', 'aspiration','carbody', 'drivewheel', 'wheelbase', 'carlength','carwidth', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 'price']], drop_first = True)
Y=df_dummy['price']
df_dummy.drop(['price'],axis=1,inplace=True)
X=df_dummy
X_1 = sm.add_constant(X)
model = sm.OLS(Y,X_1)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     81.09
# Date:                Mon, 22 Jan 2024   Prob (F-statistic):           4.86e-89
# Time:                        22:32:06   Log-Likelihood:                -1804.2
# No. Observations:                 205   AIC:                             3702.
# Df Residuals:                     158   BIC:                             3858.
# Df Model:                          46
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
df_dummy = pd.get_dummies(data=cars[['company', 'fueltype', 'aspiration','carbody', 'drivewheel', 'wheelbase', 'carlength','carwidth', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 'price']], drop_first = True)
Y=df_dummy['price']
df_dummy.drop(['price'],axis=1,inplace=True)
columns_to_drop = df_dummy.filter(like='company').columns
X = df_dummy.drop(columns=columns_to_drop)
X_1 = sm.add_constant(X)
model = sm.OLS(Y,X_1)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     72.32
# Date:                Mon, 22 Jan 2024   Prob (F-statistic):           9.86e-81
# Time:                        22:32:07   Log-Likelihood:                -1881.6
# No. Observations:                 205   AIC:                             3817.
# Df Residuals:                     178   BIC:                             3907.
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
# Получаем p-значения для всех предикторов
p_values = results.pvalues

# Считаем количество не значимых предикторов (p > 0.05)
non_significant_predictors_count = sum(p_values > 0.05)

non_significant_predictors_count
# Out:
# 11

# %%
cars_data_without_specific_columns
# Out:
#      wheelbase  carlength  carwidth  curbweight  enginesize  boreratio  \
# 0         88.6      168.8      64.1        2548         130       3.47
# 1         88.6      168.8      64.1        2548         130       3.47
# 2         94.5      171.2      65.5        2823         152       2.68
# 3         99.8      176.6      66.2        2337         109       3.19
# 4         99.4      176.6      66.4        2824         136       3.19
# ..         ...        ...       ...         ...         ...        ...
# 200      109.1      188.8      68.9        2952         141       3.78
# 201      109.1      188.8      68.8        3049         141       3.78
# 202      109.1      188.8      68.9        3012         173       3.58
# 203      109.1      188.8      68.9        3217         145       3.01
# 204      109.1      188.8      68.9        3062         141       3.78
#
#      horsepower  fueltype_gas  aspiration_turbo  carbody_hardtop  ...  \
# ...

# %%
categorical_predictors
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem      company
# ...
