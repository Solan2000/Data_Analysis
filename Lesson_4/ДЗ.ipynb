# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/3_taxi_peru.csv', sep=';',parse_dates=['start_at', 'end_at','arrived_at'])
df
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
df.isna().sum()#1задание
# Out:
# journey_id              0
# user_id                 0
# driver_id            3385
# taxi_id              3385
# icon                    0
# start_type              0
# start_at                0
# start_lat               0
# start_lon               0
# end_at                276
# end_lat                 0
# end_lon                 0
# end_state              12
# driver_start_lat     3490
# driver_start_lon     3490
# arrived_at           5395
# source                123
# driver_score        15461
# rider_score          7721
# dtype: int64

# %%
numbers = [1, -2, 3, 0, -3, 2] #7 задание
positive_numbers = []
for i in numbers:
    if i>0:
        positive_numbers.append(i)
    elif i<0:
        continue
    else:
        break
positive_numbers
# Out:
# [1, 3]

# %%
df['start_at']=pd.to_datetime(df.start_at,dayfirst=True) #8 задание
df['end_at']=pd.to_datetime(df.end_at,dayfirst=True)
df['arrived_at']=pd.to_datetime(df.arrived_at ,dayfirst=True)
df=df.query("start_type=='asap' or start_type=='reserved'")

# %%
df=pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/3_taxi_peru.csv', sep=';',parse_dates=['start_at', 'end_at','arrived_at'])
df['wait_time']=df.arrived_at - df.start_at #9зададние
df.wait_time=df.wait_time.astype('timedelta64[m]')
df.wait_time
df.head(10)
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# 5  2254715f0f569e3173ec61f16cbb8341  56772d544fdfa589a020a1ff894a86f7
# 6  12432d83b49393bf25164673212b8295  56772d544fdfa589a020a1ff894a86f7
# 7  2e51db3a8a77aa594aa686ff19fe6036  56772d544fdfa589a020a1ff894a86f7
# 8  0234eb5f7e99d581c72052f0a868289c  0234eb5f7e99d581c72052f0a869293a
# 9  9448070ece760ea5386e5d4822121a6c  dd23cf0ef33ae44e0c0b4c756e1fe4e8
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# ...

# %%
df=pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/3_taxi_peru.csv', sep=';',parse_dates=['start_at', 'end_at','arrived_at'])
df['wait_time']=df.arrived_at - df.start_at #10зададние
df.wait_time=df.wait_time.astype('timedelta64[m]')
df['count']=1
df=df.query("wait_time>0.0 and start_type == 'reserved'")
df_max=df.groupby('driver_id').agg({'count':'sum'}).idxmax()
df_max
# Out:
# count    406921adcca37705ef527b4246c0cfea
# dtype: object

# %%
df=pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/3_taxi_peru.csv', sep=';',parse_dates=['start_at', 'end_at','arrived_at'])
df['month']=df['start_at'].dt.month #12задание
df['weekday']=df['start_at'].dt.day_name()
df
# Out:
#                              journey_id                           user_id  \
# 0      23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1      dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2      dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3      dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4      85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
# ...                                 ...                               ...
# 23106  4a18ea5737ce0ffecaf20b305a0e2c86  8998bb370b5f0cec43a373adebba0c72
# 23107  f1e4317f2c17991dd90d1cd17ae0d399  5f8a6ffef0ea5df78a8ee890267b60ec
# 23108  1e44c0fd0a266c3719ff30410b257bce  c0ffb6f6cd801004dd8609c12277c2d1
# 23109  7073883383b89ad289e864022150cdd7  c0ffb6f6cd801004dd8609c12277c2d1
# 23110  b7dea45c3cc92b9efd5a4905e69ff9bf  c0ffb6f6cd801004dd8609c12277c2d1
#
#                               driver_id                           taxi_id  \
# ...

# %%
sns.countplot(df.month)#13 задание
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['weekday'], order=['Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday','Sunday']) #14 задание
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df=pd.read_csv('/mnt/HC_Volume_18315164/home-jupyter/jupyter-a-zakorko/3_taxi_peru.csv', sep=';',parse_dates=['start_at', 'end_at','arrived_at'])
df['month']=df['start_at'].dt.month #15задание
df['weekday']=df['start_at'].dt.day_name()
df=df.groupby('month',as_index=False).agg({'user_id':'nunique'})
sns.lineplot(df.user_id, df.month)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
